# %%
import importlib
import src.ui.main
import src.config
importlib.reload(src.ui.main)
importlib.reload(src.config)

from src.ui.main import AnalysisUI
from src.config import AppConfig

# --- Configuration ---
# Initialize configuration with default values
config = AppConfig()

# 1. Data Source Config
config.data.source_type = 'file'       # Options: 'file' or 'gen'
config.data.path_noised = 'data/NOISED.tiff'
config.data.path_original = 'data/ORIGINAL.tiff'
# config.data.path_noised = 'data/NOISED_2.png'
# config.data.path_original = 'data/ORIGINAL_2.png'
config.data.gen_noise_level = 0.05

# 2. VST Parameters
config.vst.a = 8.39
config.vst.b = 1.2

# 3. Experiment Settings
config.experiment.q_start = 20
config.experiment.q_end = 51
config.experiment.q_step = 1

# 4. Plotting & Export Config
config.plotting.show_plots = True      # Show in notebook
config.plotting.save_plots = True      # Auto-save to disk
config.plotting.dpi = 300              # High-res output
config.plotting.cmap = 'bwr'           # Colormap for error maps
config.export.results_dir = 'results'  # Output directory
config.export.save_csv = True  # Output directory
config.export.save_oop_images = True  # Output directory

# Initialize UI with the custom configuration
ui = AnalysisUI(config)
ui.show()
